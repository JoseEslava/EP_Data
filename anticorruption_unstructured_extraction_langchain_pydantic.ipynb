# %% [markdown]
# # Extraccion de datos no estructurados
# de un archivo CSV usando `PydanticOutputParser`

# %% [markdown]
# Imports

# %%
import pandas as pd
import json
import unicodedata

from typing import Optional, Sequence
from langchain.output_parsers import PydanticOutputParser
from transformers import pipeline
from pydantic import BaseModel, Field

# %% [markdown]
# carga de datos en un Dataframe

# %%
# Carga de datos desde un CSV
df = pd.read_csv("df_combined.csv", sep=',', encoding='utf-8')

# %%
df.head()
# Out:
#                          id  \
# 0  630d3b3390bf7b1af7b620f6
# 1  630d3b3390bf7b1af7b620f7
# 2  630d3b3390bf7b1af7b620f8
# 3  630d3b3390bf7b1af7b620f9
# 4  630d3b3390bf7b1af7b620fa
#
#                               institucionDependencia  CVE_ENT  \
# 0  INSTITUTO DE SEGURIDAD Y SERVICIOS SOCIALES DE...       24
# 1                    GOBIERNO DE LA CIUDAD DE MEXICO        9
# 2                      GOBIERNO DEL ESTADO DE PUEBLA       21
# 3                  GOBIERNO DEL ESTADO DE GUANAJUATO       11
# 4                     GOBIERNO DEL ESTADO DE HIDALGO       13
#
#                 Tipo_organismo_poder Funcionalidad de la institución  \
# 0  Organismo público descentralizado                Seguridad Social
# 1                   Gobierno estatal                        Gobierno
# 2                   Gobierno estatal                        Gobierno
# 3                   Gobierno estatal                        Gobierno
# 4                   Gobierno estatal                        Gobierno
#
#                            servidorPublicoSancionado  Sexo  \
# 0  {'nombres': 'ZULAIDA', 'primerApellido': 'SILV...     1
# 1  {'nombres': 'YONATAN', 'primerApellido': 'SALA...     0
# 2  {'nombres': 'YOLANDA', 'primerApellido': 'CORT...     1
# 3  {'nombres': 'YOLANDA', 'primerApellido': 'CHAV...     1
# 4  {'nombres': 'YOLANDA', 'primerApellido': 'TELL...     1
#
#                           resolucion  \
# 0  {'fechaResolucion': '06/08/2018'}
# 1  {'fechaResolucion': '27/06/2013'}
# 2  {'fechaResolucion': '11/06/2018'}
# 3  {'fechaResolucion': '29/02/2016'}
# 4  {'fechaResolucion': '04/12/2020'}
#
#                                       inhabilitacion fechaCaptura  ...  \
# 0  {'fechaInicial': '06/08/2018', 'fechaFinal': '...   31/01/2019  ...
# 1  {'fechaInicial': '27/06/2013', 'fechaFinal': '...   18/05/2015  ...
# 2  {'fechaInicial': '11/06/2018', 'fechaFinal': '...   18/07/2018  ...
# 3  {'fechaInicial': '29/02/2016', 'fechaFinal': '...   15/06/2017  ...
# 4  {'fechaInicial': '08/12/2020', 'fechaFinal': '...   08/12/2020  ...
#
#        autoridadSancionadora   tipoSancion  \
# 0  ORGANO INTERNO DE CONTROL  INHABILITADO
# 1      CONTRALORIA DE ESTADO  INHABILITADO
# 2       JUZGADOS DE DISTRITO  INHABILITADO
# 3      CONTRALORIA MUNICIPAL  INHABILITADO
# 4      CONTRALORIA DE ESTADO  INHABILITADO
#
#                        Causa_motivo_hechos  \
# 0               NEGLIGENCIA ADMINISTRATIVA
# 1               NEGLIGENCIA ADMINISTRATIVA
# 2  DELITO COMETIDO POR SERVIDORES PUBLICOS
# 3                       ABUSO DE AUTORIDAD
# 4               NEGLIGENCIA ADMINISTRATIVA
#
#                                        observaciones  \
# 0  NO REALIZ� UNA ADECUADA DEFENSA JUR�DICA DENTR...
# 1                                   NO LOS PRECISAN.
# 2  YOLANDA CORT�S BALTAZAR, ES PENALMENTE RESPONS...
# 3  DUPLICIDAD DE CARGOS PUBLICOS EN EL JUZGADO AD...
# 4  DEPENDENCIA: MUNICIPIO DE PACHUCA, HIDALGO. \r...
#
#                                              Puesto  Nivel_salarial  \
# 0                            SUBJEFE DE DEPARTAMENTO              8
# 1      RESIDENTE DE OBRA. SR�A. DEOBRAS Y SERVICIOS.              8
# 2  REGIDOR DEL CABILDO MUNICIPAL DEL AYUNTAMIENTO...             10
# 3                                         SECRETARIA              8
# 4                            EX PRESIDENTA MUNICIPAL              5
#
#              Nivel_mando salario_estimado meses_inhabil  Nivel_mando2
# 0     Personal de enlace            17919         120.0             3
# 1     Personal de enlace            17919         132.0             3
# 2  enlace_oper_categoria            27000          40.0             3
# 3     Personal de enlace            17919         120.0             3
# 4  Presidencia municipal            45000          12.0             2
#
# [5 rows x 21 columns]

# %%
# Convertir una columna en diccionarios
def expand_json_column(json_string):
    try:
        # Reemplazar comillas simples por dobles y eliminar espacios extra
        clean_json = json_string.strip().replace("'", '"')
        # Convertir a un diccionario
        return json.loads(clean_json)
    except json.JSONDecodeError:
        return {}  # Devuelve un diccionario vacío si hay un error

# Función para limpiar y corregir caracteres especiales mientras se preservan los acentos
def clean_text_preserve_accents(text):
    try:
        # Convertir a texto (str) y normalizar para corregir caracteres especiales
        text = str(text)
        text = unicodedata.normalize('NFKD', text).encode('latin-1', 'ignore').decode('utf-8')
        return text
    except Exception as e:
        return text  # Devuelve el texto original si ocurre algún error

# %%
# Aplicar la función a la columna 'info'
expanded_data = df['servidorPublicoSancionado'].apply(expand_json_column)
# Crear nuevas columnas a partir de los datos expandidos
expanded_df = pd.json_normalize(expanded_data)
# Combinar el DataFrame original con las nuevas columnas
df = pd.concat([df, expanded_df], axis=1)
# Eliminar la columna original si ya no es necesaria
df = df.drop(columns=['servidorPublicoSancionado'])

# Aplicar la función a la columna 'info'
expanded_data = df['resolucion'].apply(expand_json_column)
# Crear nuevas columnas a partir de los datos expandidos
expanded_df = pd.json_normalize(expanded_data)
# Combinar el DataFrame original con las nuevas columnas
df = pd.concat([df, expanded_df], axis=1)
# Eliminar la columna original si ya no es necesaria
df = df.drop(columns=['resolucion'])

# Aplicar la función a la columna 'info'
expanded_data = df['inhabilitacion'].apply(expand_json_column)
# Crear nuevas columnas a partir de los datos expandidos
expanded_df = pd.json_normalize(expanded_data)
# Combinar el DataFrame original con las nuevas columnas
df = pd.concat([df, expanded_df], axis=1)
# Eliminar la columna original si ya no es necesaria
df = df.drop(columns=['inhabilitacion'])

# Aplicar la limpieza a la columna 'descripcion'
df['observaciones'] = df['observaciones'].apply(clean_text_preserve_accents)
df['puesto'] = df['puesto'].apply(clean_text_preserve_accents)

df['observaciones'] = df['observaciones'].astype(str)
df['puesto'] = df['puesto'].astype(str)

# %%
df.head()
# Out:
#                          id  \
# 0  630d3b3390bf7b1af7b620f6
# 1  630d3b3390bf7b1af7b620f7
# 2  630d3b3390bf7b1af7b620f8
# 3  630d3b3390bf7b1af7b620f9
# 4  630d3b3390bf7b1af7b620fa
#
#                               institucionDependencia  CVE_ENT  \
# 0  INSTITUTO DE SEGURIDAD Y SERVICIOS SOCIALES DE...       24
# 1                    GOBIERNO DE LA CIUDAD DE MEXICO        9
# 2                      GOBIERNO DEL ESTADO DE PUEBLA       21
# 3                  GOBIERNO DEL ESTADO DE GUANAJUATO       11
# 4                     GOBIERNO DEL ESTADO DE HIDALGO       13
#
#                 Tipo_organismo_poder Funcionalidad de la institución  Sexo  \
# 0  Organismo público descentralizado                Seguridad Social     1
# 1                   Gobierno estatal                        Gobierno     0
# 2                   Gobierno estatal                        Gobierno     1
# 3                   Gobierno estatal                        Gobierno     1
# 4                   Gobierno estatal                        Gobierno     1
#
#   fechaCaptura               expediente      autoridadSancionadora  \
# 0   31/01/2019              000930/2015  ORGANO INTERNO DE CONTROL
# 1   18/05/2015       CI/SOS/A/0083/2012      CONTRALORIA DE ESTADO
# 2   18/07/2018  PUE/51/2018 CAUSA PENAL       JUZGADOS DE DISTRITO
# 3   15/06/2017              PRA-02/2015      CONTRALORIA MUNICIPAL
# 4   08/12/2020             PRA/015/2020      CONTRALORIA DE ESTADO
#
#     tipoSancion  ... meses_inhabil Nivel_mando2  nombres  primerApellido  \
# 0  INHABILITADO  ...         120.0            3  ZULAIDA           SILVA
# 1  INHABILITADO  ...         132.0            3  YONATAN           SALAS
# 2  INHABILITADO  ...          40.0            3  YOLANDA          CORTES
# 3  INHABILITADO  ...         120.0            3  YOLANDA          CHAVEZ
# 4  INHABILITADO  ...          12.0            2  YOLANDA        TELLERIA
#
#   segundoApellido                                             puesto  \
# 0         SOLORIO                            SUBJEFE DE DEPARTAMENTO
# 1         ALARCON       RESIDENTE DE OBRA. SRA. DEOBRAS Y SERVICIOS.
# 2        BALTAZAR  REGIDOR DEL CABILDO MUNICIPAL DEL AYUNTAMIENTO...
# 3         CENTENO                                         SECRETARIA
# 4         BELTRAN                            EX PRESIDENTA MUNICIPAL
#
#    fechaResolucion  fechaInicial  fechaFinal                  plazo
# 0       06/08/2018    06/08/2018  06/08/2028  Dato no proporcionado
# 1       27/06/2013    27/06/2013  23/06/2024  Dato no proporcionado
# 2       11/06/2018    11/06/2018  10/10/2021  Dato no proporcionado
# 3       29/02/2016    29/02/2016  25/02/2026  Dato no proporcionado
# 4       04/12/2020    08/12/2020  08/12/2021  Dato no proporcionado
#
# [5 rows x 26 columns]

# %% [markdown]
# Crear una estrcutra de datos Pydantic para el caso de uso

# %%
# Modelos Pydantic para el caso de negocio inteligencia competitiva
class Sancionados(BaseModel):
    delito: str = Field(description="tipo de delito jurídico")
    resolucion: str = Field(description="tipo de castigo imputado")
    ubicacion: str = Field(description="lugar donde se aborda el caso")
    productos_servicios: str = Field(description="producto o servicio del que deriva el delito")
    detalles_adicionales: str = Field(description="cualquier otro detalle sobre el delito")

class Delito(BaseModel):
    """Identificar información sobre cada competidor"""
    persona: Sequence[Sancionados]

# Preguntas para extraer características específicas
preguntas = {
    "delito": "¿Es un tipo de delito sexual? Si es así identifica el delito",
    "resolucion": "¿Cuál es el castigo imputado al delito identificado?",
    "ubicacion": "¿En que estado de la república mexicana se determinó la resolución?",
    "productos_servicios": "¿Qué producto o servicio fue objeto del delito?",
    "detalles_adicionales": "¿Qué otros detalles relevantes se mencionan sobre el delito?"
}

# Inicializamos el modelo de Hugging Face para tareas de extracción de información
extractor = pipeline("question-answering", model="timpal0l/mdeberta-v3-base-squad2")

# Configuracion del parser Pydantic y prompt template
parser = PydanticOutputParser(pydantic_object=Delito)
# Out:
# WARNING:tensorflow:From C:\Users\jesla\AppData\Roaming\Python\Python310\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# C:\Users\jesla\AppData\Roaming\Python\Python310\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %% [markdown]
# Función para procesar cada fila de datos y extraer informacion

# %%
# Función para procesar cada fila de datos y extraer informacion
def process_row(row):
    respuestas = {}
    for campo, pregunta in preguntas.items():
      # Convert 'observaciones' to string to ensure compatibility
        context = str(row['observaciones'])

        respuesta = extractor(question=pregunta, context= context)
        respuestas[campo] = respuesta['answer']

    persona_data = [Sancionados(**respuestas)]
    sancionado_data = Delito(persona=persona_data)
    json_data = sancionado_data.json()

    result = parser.parse(json_data)

    # Convert Pydantic result to a dictionary
    persona_data = result.model_dump()

    # Flatten the nested structure for DataFrame creation
    flat_data = {'CVE_ENT': [], 'delito': [], 'resolucion': [], 'ubicacion': [], 'productos_servicios': [], 'detalles_adicionales': []}

    for entry in persona_data['persona']:
        flat_data['CVE_ENT'].append(row['CVE_ENT'])
        flat_data['delito'].append(entry['delito'])
        flat_data['resolucion'].append(entry['resolucion'])
        flat_data['ubicacion'].append(entry['ubicacion'])
        flat_data['productos_servicios'].append(entry['productos_servicios'])
        flat_data['detalles_adicionales'].append(entry['detalles_adicionales'])

    # Create a DataFrame from the flattened data
    df_delito = pd.DataFrame(flat_data)

    return df_delito

# %% [markdown]
# Aplica la funcion a cada fila y concatena los resultados

# %%
# Aplica la funcion a cada fila y concatena los resultados
intel_df = pd.concat(df.apply(process_row, axis=1).tolist(), ignore_index=True)

# %% [markdown]
# Muestra los datos obtenidos

# %%
# Despliega el DataFrame con datos estructurados
intel_df.head(5)
# Out:
#    CVE_ENT                                  delito  \
# 0       24  NO REALIZ UNA ADECUADA DEFENSA JURDICA
# 1        9                        NO LOS PRECISAN.
# 2       21                          A TTULO DOLOSO
# 3       11           DUPLICIDAD DE CARGOS PUBLICOS
# 4       13   ALS NORMAS SEALAN PARA TALES EFECTOS.
#
#                                resolucion  \
# 0  NO REALIZ UNA ADECUADA DEFENSA JURDICA
# 1                        NO LOS PRECISAN.
# 2                    SENTENCIA DE AMPARO.
# 3           DUPLICIDAD DE CARGOS PUBLICOS
# 4                   INDEBIDA Y ARBITRARIA
#
#                                   ubicacion  \
# 0                            SAN LUIS POTOS
# 1                          NO LOS PRECISAN.
# 2                                   PUEBLA,
# 3  \r\nAUTORIDAD SANCIONADORA: SALVATIERRA.
# 4                 PACHUCA DE SOTO, HIDALGO.
#
#                       productos_servicios  \
# 0  NO REALIZ UNA ADECUADA DEFENSA JURDICA
# 1                        NO LOS PRECISAN.
# 2                         SERVIDOR PBLICO
# 3         EMPLEO, CARGO O COMISIN PBLICO,
# 4       LA INDEBIDA Y ARBITRARIA CREACION
#
#                               detalles_adicionales
# 0           NO REALIZ UNA ADECUADA DEFENSA JURDICA
# 1                                 NO LOS PRECISAN.
# 2   PRECEPTOS 9, PRRAFO PRIMERO Y 13, FRACCIN III,
# 3                    DUPLICIDAD DE CARGOS PUBLICOS
# 4                        TODOS LOS EFECTOS LEGALES

# %%
intel_df.to_csv('anticorrupcion_intel.csv', index=False)

# %%
intel_df.to_pickle('anticorrupcion.pkl')
